# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/DataSets/student-mat.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
columns_of_interest1 = ['age', 'G1', 'G2', 'G3', 'studytime', 'failures','traveltime','freetime']

# %%
columns_of_interest2 = [ 'studytime','freetime']

# %%
subset_data = df[columns_of_interest2]

# %%
correlation_matrix = subset_data.corr()

# %%
covariance_matrix = subset_data.cov()

# %%
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#            studytime  freetime
# studytime   1.000000 -0.143198
# freetime   -0.143198  1.000000

# %%
sns.heatmap(correlation_matrix,cmap ="YlGnBu")
plt.show()

# %%
print("\nCovariance Matrix:")
print(covariance_matrix)
# Out:
# Covariance Matrix:
#            studytime  freetime
# studytime   0.704324 -0.120041
# freetime   -0.120041  0.997725

# %%
sns.heatmap(covariance_matrix,cmap ="coolwarm")
plt.show()

# %%
subset_data2 = df[columns_of_interest1]

# %%
correlation_matrix2 = subset_data2.corr()

# %%
covariance_matrix2 = subset_data2.cov()

# %%
print("Correlation Matrix:")
print(correlation_matrix2)
# Out:
# Correlation Matrix:
#                  age        G1        G2        G3  studytime  failures  \
# age         1.000000 -0.064081 -0.143474 -0.161579  -0.004140  0.243665
# G1         -0.064081  1.000000  0.852118  0.801468   0.160612 -0.354718
# G2         -0.143474  0.852118  1.000000  0.904868   0.135880 -0.355896
# G3         -0.161579  0.801468  0.904868  1.000000   0.097820 -0.360415
# studytime  -0.004140  0.160612  0.135880  0.097820   1.000000 -0.173563
# failures    0.243665 -0.354718 -0.355896 -0.360415  -0.173563  1.000000
# traveltime  0.070641 -0.093040 -0.153198 -0.117142  -0.100909  0.092239
# freetime    0.016434  0.012613 -0.013777  0.011307  -0.143198  0.091987
#
#             traveltime  freetime
# age           0.070641  0.016434
# G1           -0.093040  0.012613
# G2           -0.153198 -0.013777
# G3           -0.117142  0.011307
# studytime    -0.100909 -0.143198
# failures      0.092239  0.091987
# traveltime    1.000000 -0.017025
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix2,annot=True,cmap ="viridis")
print("Correlation Matrix:")
print(correlation_matrix2)
plt.show()
# Out:
# Correlation Matrix:
#                  age        G1        G2        G3  studytime  failures  \
# age         1.000000 -0.064081 -0.143474 -0.161579  -0.004140  0.243665
# G1         -0.064081  1.000000  0.852118  0.801468   0.160612 -0.354718
# G2         -0.143474  0.852118  1.000000  0.904868   0.135880 -0.355896
# G3         -0.161579  0.801468  0.904868  1.000000   0.097820 -0.360415
# studytime  -0.004140  0.160612  0.135880  0.097820   1.000000 -0.173563
# failures    0.243665 -0.354718 -0.355896 -0.360415  -0.173563  1.000000
# traveltime  0.070641 -0.093040 -0.153198 -0.117142  -0.100909  0.092239
# freetime    0.016434  0.012613 -0.013777  0.011307  -0.143198  0.091987
#
#             traveltime  freetime
# age           0.070641  0.016434
# G1           -0.093040  0.012613
# G2           -0.153198 -0.013777
# G3           -0.117142  0.011307
# studytime    -0.100909 -0.143198
# failures      0.092239  0.091987
# traveltime    1.000000 -0.017025
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix2,annot=True,cmap ="plasma")
print("Covariance Matrix:")
print(covariance_matrix2)
plt.show()
# Out:
# Covariance Matrix:
#                  age         G1         G2         G3  studytime  failures  \
# age         1.628285  -0.271413  -0.688653  -0.944612  -0.004434  0.231221
# G1         -0.271413  11.017053  10.638836  12.187682   0.447401 -0.875557
# G2         -0.688653  10.638836  14.148917  15.593697   0.428947 -0.995528
# G3         -0.944612  12.187682  15.593697  20.989616   0.376110 -1.227932
# studytime  -0.004434   0.447401   0.428947   0.376110   0.704324 -0.108321
# failures    0.231221  -0.875557  -0.995528  -1.227932  -0.108321  0.553017
# traveltime  0.062873  -0.215402  -0.401940  -0.374337  -0.059070  0.047844
# freetime    0.020947   0.041817  -0.051764   0.051745  -0.120041  0.068329
#
#             traveltime  freetime
# age           0.062873  0.020947
# G1           -0.215402  0.041817
# G2           -0.401940 -0.051764
# G3           -0.374337  0.051745
# studytime    -0.059070 -0.120041
# failures      0.047844  0.068329
# traveltime    0.486513 -0.011861
# ...

# %%
binary_attributes = ['school', 'sex', 'address', 'famsize', 'Pstatus', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']

# %%
binary_data = df[binary_attributes].apply(lambda x: x.map({'no': 0, 'yes': 1}))

# %%
correlation_matrix3 = binary_data.corr()

# %%
covariance_matrix3= binary_data.cov()

# %%
print("Correlation Matrix:")
print(correlation_matrix3)
# Out:
# Correlation Matrix:
#             school  sex  address  famsize  Pstatus  schoolsup    famsup  \
# school         NaN  NaN      NaN      NaN      NaN        NaN       NaN
# sex            NaN  NaN      NaN      NaN      NaN        NaN       NaN
# address        NaN  NaN      NaN      NaN      NaN        NaN       NaN
# famsize        NaN  NaN      NaN      NaN      NaN        NaN       NaN
# Pstatus        NaN  NaN      NaN      NaN      NaN        NaN       NaN
# schoolsup      NaN  NaN      NaN      NaN      NaN   1.000000  0.104681
# famsup         NaN  NaN      NaN      NaN      NaN   0.104681  1.000000
# paid           NaN  NaN      NaN      NaN      NaN  -0.020753  0.293184
# activities     NaN  NaN      NaN      NaN      NaN   0.046032 -0.001500
# nursery        NaN  NaN      NaN      NaN      NaN   0.045967  0.059536
# higher         NaN  NaN      NaN      NaN      NaN   0.054486  0.100815
# internet       NaN  NaN      NaN      NaN      NaN  -0.009683  0.103581
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix3,annot=True,cmap ="viridis")
plt.show()

# %%
print("\nCovariance Matrix:")
print(covariance_matrix3)
# Out:
# Covariance Matrix:
#             school  sex  address  famsize  Pstatus  schoolsup    famsup  \
# school         NaN  NaN      NaN      NaN      NaN        NaN       NaN
# sex            NaN  NaN      NaN      NaN      NaN        NaN       NaN
# address        NaN  NaN      NaN      NaN      NaN        NaN       NaN
# famsize        NaN  NaN      NaN      NaN      NaN        NaN       NaN
# Pstatus        NaN  NaN      NaN      NaN      NaN        NaN       NaN
# schoolsup      NaN  NaN      NaN      NaN      NaN   0.112729  0.017143
# famsup         NaN  NaN      NaN      NaN      NaN   0.017143  0.237910
# paid           NaN  NaN      NaN      NaN      NaN  -0.003476  0.071342
# activities     NaN  NaN      NaN      NaN      NaN   0.007736 -0.000366
# nursery        NaN  NaN      NaN      NaN      NaN   0.006239  0.011739
# higher         NaN  NaN      NaN      NaN      NaN   0.004016  0.010795
# internet       NaN  NaN      NaN      NaN      NaN  -0.001214  0.018872
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(covariance_matrix3,annot=True,cmap ="plasma")
plt.show()
